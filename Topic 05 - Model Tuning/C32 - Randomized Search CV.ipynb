# %% [markdown]
# # Randommized seach CV

# %% [markdown]
# ## Setting up

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Load data
dataObj = load_breast_cancer()
X = dataObj.data
y = dataObj.target

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X, y, 
    stratify=y,
    test_size=0.20,
    random_state=1)

# %%
from sklearn.svm import SVC

pipe_svc = Pipeline([('scl', StandardScaler()),
            ('clf', SVC(random_state=1))])

# %%
# Get parameter names
for k, v in pipe_svc.get_params().items():
    print(f"{k:35.35s}: {str(v):35.35s}...")
# Out:
# memory                             : None                               ...
# steps                              : [('scl', StandardScaler()), ('clf',...
# verbose                            : False                              ...
# scl                                : StandardScaler()                   ...
# clf                                : SVC(random_state=1)                ...
# scl__copy                          : True                               ...
# scl__with_mean                     : True                               ...
# scl__with_std                      : True                               ...
# clf__C                             : 1.0                                ...
# clf__break_ties                    : False                              ...
# clf__cache_size                    : 200                                ...
# clf__class_weight                  : None                               ...
# clf__coef0                         : 0.0                                ...
# clf__decision_function_shape       : ovr                                ...
# clf__degree                        : 3                                  ...
# clf__gamma                         : scale                              ...
# clf__kernel                        : rbf                                ...
# clf__max_iter                      : -1                                 ...
# clf__probability                   : False                              ...
# clf__random_state                  : 1                                  ...
# clf__shrinking                     : True                               ...
# clf__tol                           : 0.001                              ...
# clf__verbose                       : False                              ...

# %%
param_range = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]

set1 = {'clf__C': param_range,
        'clf__kernel': ['linear']}

set2 = {'clf__C': param_range,
        'clf__gamma': param_range,
        'clf__kernel': ['rbf']}

param_grid = [set1, set2]

# %%
from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(estimator=pipe_svc, 
                  param_distributions=param_grid,
                  n_iter = 10,
                  scoring='accuracy', 
                  cv=10,
                  n_jobs=-1)

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('scl', StandardScaler()),
#                                              ('clf', SVC(random_state=1))]),
#                    n_jobs=-1,
#                    param_distributions=[{'clf__C': [0.0001, 0.001, 0.01, 0.1,
#                                                     1.0, 10.0, 100.0, 1000.0],
#                                          'clf__kernel': ['linear']},
#                                         {'clf__C': [0.0001, 0.001, 0.01, 0.1,
#                                                     1.0, 10.0, 100.0, 1000.0],
#                                          'clf__gamma': [0.0001, 0.001, 0.01,
#                                                         0.1, 1.0, 10.0, 100.0,
#                                                         1000.0],
#                                          'clf__kernel': ['rbf']}],
#                    scoring='accuracy')

# %%
# Get parameter names
for k, v in rs.get_params().items():
    print(f"{k:35.35s}: {str(v):35.35}...")
# Out:
# cv                                 : 10                                 ...
# error_score                        : nan                                ...
# estimator__memory                  : None                               ...
# estimator__steps                   : [('scl', StandardScaler()), ('clf',...
# estimator__verbose                 : False                              ...
# estimator__scl                     : StandardScaler()                   ...
# estimator__clf                     : SVC(random_state=1)                ...
# estimator__scl__copy               : True                               ...
# estimator__scl__with_mean          : True                               ...
# estimator__scl__with_std           : True                               ...
# estimator__clf__C                  : 1.0                                ...
# estimator__clf__break_ties         : False                              ...
# estimator__clf__cache_size         : 200                                ...
# estimator__clf__class_weight       : None                               ...
# estimator__clf__coef0              : 0.0                                ...
# estimator__clf__decision_function_s: ovr                                ...
# estimator__clf__degree             : 3                                  ...
# estimator__clf__gamma              : scale                              ...
# estimator__clf__kernel             : rbf                                ...
# estimator__clf__max_iter           : -1                                 ...
# estimator__clf__probability        : False                              ...
# estimator__clf__random_state       : 1                                  ...
# estimator__clf__shrinking          : True                               ...
# estimator__clf__tol                : 0.001                              ...
# estimator__clf__verbose            : False                              ...
# estimator                          : Pipeline(steps=[('scl', StandardSca...
# n_iter                             : 10                                 ...
# n_jobs                             : -1                                 ...
# param_distributions                : [{'clf__C': [0.0001, 0.001, 0.01, 0...
# pre_dispatch                       : 2*n_jobs                           ...
# random_state                       : None                               ...
# refit                              : True                               ...
# return_train_score                 : False                              ...
# scoring                            : accuracy                           ...
# verbose                            : 0                                  ...

# %%
df = pd.DataFrame(rs.cv_results_)
display(df)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009602      0.000490         0.002501        0.000500
# 1       0.009302      0.001487         0.001901        0.000538
# 2       0.008902      0.000539         0.002101        0.000539
# 3       0.023705      0.004027         0.004601        0.000490
# 4       0.004501      0.001204         0.000600        0.000490
# 5       0.006301      0.000458         0.001700        0.000458
# 6       0.025006      0.001484         0.004501        0.000500
# 7       0.007802      0.001400         0.001900        0.000539
# 8       0.018004      0.001484         0.003601        0.000663
# 9       0.009705      0.001007         0.001998        0.000633
#
#   param_clf__kernel param_clf__gamma param_clf__C  \
# 0               rbf             0.01        0.001
# 1               rbf              1.0       0.0001
# 2               rbf              0.1          0.1
# 3               rbf           1000.0          1.0
# 4            linear              NaN         0.01
# 5               rbf           0.0001         10.0
# 6               rbf           1000.0       1000.0
# 7               rbf              0.1          1.0
# 8               rbf             10.0       1000.0
# 9               rbf           0.0001          1.0
#
#                                               params  split0_test_score  \
# 0  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...           0.630435
# 1  {'clf__kernel': 'rbf', 'clf__gamma': 1.0, 'clf...           0.630435
# 2  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...           0.978261
# 3  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...           0.630435
# 4          {'clf__kernel': 'linear', 'clf__C': 0.01}           0.978261
# 5  {'clf__kernel': 'rbf', 'clf__gamma': 0.0001, '...           0.978261
# 6  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...           0.630435
# 7  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...           0.978261
# 8  {'clf__kernel': 'rbf', 'clf__gamma': 10.0, 'cl...           0.630435
# 9  {'clf__kernel': 'rbf', 'clf__gamma': 0.0001, '...           0.826087
#
#    split1_test_score  ...  split3_test_score  split4_test_score  \
# 0           0.630435  ...           0.630435           0.630435
# 1           0.630435  ...           0.630435           0.630435
# 2           0.913043  ...           0.956522           0.891304
# 3           0.630435  ...           0.630435           0.630435
# 4           0.956522  ...           0.956522           0.956522
# 5           0.913043  ...           0.956522           0.913043
# 6           0.630435  ...           0.630435           0.630435
# 7           0.934783  ...           0.978261           0.913043
# 8           0.630435  ...           0.630435           0.630435
# 9           0.695652  ...           0.826087           0.739130
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.622222           0.622222           0.622222           0.622222
# 1           0.622222           0.622222           0.622222           0.622222
# 2           0.955556           0.888889           0.955556           0.933333
# 3           0.622222           0.622222           0.622222           0.622222
# 4           0.977778           0.955556           0.977778           0.955556
# 5           0.955556           0.933333           0.955556           0.933333
# 6           0.622222           0.622222           0.622222           0.622222
# 7           1.000000           0.933333           0.977778           0.955556
# 8           0.622222           0.622222           0.622222           0.622222
# 9           0.822222           0.688889           0.688889           0.777778
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.622222         0.626329        0.004106                6
# 1           0.622222         0.626329        0.004106                6
# 2           0.955556         0.934106        0.029320                4
# 3           0.622222         0.626329        0.004106                6
# 4           0.977778         0.964879        0.010637                1
# 5           0.955556         0.942899        0.019870                3
# 6           0.622222         0.626329        0.004106                6
# 7           1.000000         0.962754        0.027733                2
# 8           0.622222         0.626329        0.004106                6
# 9           0.666667         0.751401        0.060079                5
#
# [10 rows x 21 columns]

# %%
df = df.sort_values(by=['rank_test_score'])
display(df.head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4       0.004501      0.001204         0.000600        0.000490
# 7       0.007802      0.001400         0.001900        0.000539
# 5       0.006301      0.000458         0.001700        0.000458
# 2       0.008902      0.000539         0.002101        0.000539
# 9       0.009705      0.001007         0.001998        0.000633
#
#   param_clf__kernel param_clf__gamma param_clf__C  \
# 4            linear              NaN         0.01
# 7               rbf              0.1          1.0
# 5               rbf           0.0001         10.0
# 2               rbf              0.1          0.1
# 9               rbf           0.0001          1.0
#
#                                               params  split0_test_score  \
# 4          {'clf__kernel': 'linear', 'clf__C': 0.01}           0.978261
# 7  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...           0.978261
# 5  {'clf__kernel': 'rbf', 'clf__gamma': 0.0001, '...           0.978261
# 2  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...           0.978261
# 9  {'clf__kernel': 'rbf', 'clf__gamma': 0.0001, '...           0.826087
#
#    split1_test_score  ...  split3_test_score  split4_test_score  \
# 4           0.956522  ...           0.956522           0.956522
# 7           0.934783  ...           0.978261           0.913043
# 5           0.913043  ...           0.956522           0.913043
# 2           0.913043  ...           0.956522           0.891304
# 9           0.695652  ...           0.826087           0.739130
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 4           0.977778           0.955556           0.977778           0.955556
# 7           1.000000           0.933333           0.977778           0.955556
# 5           0.955556           0.933333           0.955556           0.933333
# 2           0.955556           0.888889           0.955556           0.933333
# 9           0.822222           0.688889           0.688889           0.777778
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 4           0.977778         0.964879        0.010637                1
# 7           1.000000         0.962754        0.027733                2
# 5           0.955556         0.942899        0.019870                3
# 2           0.955556         0.934106        0.029320                4
# 9           0.666667         0.751401        0.060079                5
#
# [5 rows x 21 columns]

# %%
print(rs.best_score_)
print(rs.best_params_)
# Out:
# 0.9648792270531402
# {'clf__kernel': 'linear', 'clf__C': 0.01}

# %% [markdown]
# - Note that grid search already refit the entire training data with the best parameters. You can check this from this setting.

# %%
rs.refit
# Out:
# True

# %%
y_pred = rs.predict(X_test)
testing_accuracy = rs.score(X_test,y_test)
print(f"Testing accuracy: {testing_accuracy:6.3f}")
# Out:
# Testing accuracy:  0.965

# %%
# To do this manually
clf = rs.best_estimator_
clf.fit(X_train, y_train)
testing_accuracy = clf.score(X_test,y_test)
print(f"Testing accuracy: {testing_accuracy:6.3f}")
# Out:
# Testing accuracy:  0.965
