# %% [markdown]
# # Randommized seach CV

# %% [markdown]
# ## Setting up

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Load data
dataObj = load_breast_cancer()
X = dataObj.data
y = dataObj.target

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X, y, 
    stratify=y,
    test_size=0.30,
    random_state=1)

# %%
from sklearn.svm import SVC

pipe_svc = Pipeline([('scl', StandardScaler()),
            ('clf', SVC(random_state=1))])

# %%
# Get parameter names
for k, v in pipe_svc.get_params().items():
    print(f"{k:35.35s}: {str(v):35.35s}...")
# Out:
# memory                             : None                               ...
# steps                              : [('scl', StandardScaler()), ('clf',...
# verbose                            : False                              ...
# scl                                : StandardScaler()                   ...
# clf                                : SVC(random_state=1)                ...
# scl__copy                          : True                               ...
# scl__with_mean                     : True                               ...
# scl__with_std                      : True                               ...
# clf__C                             : 1.0                                ...
# clf__break_ties                    : False                              ...
# clf__cache_size                    : 200                                ...
# clf__class_weight                  : None                               ...
# clf__coef0                         : 0.0                                ...
# clf__decision_function_shape       : ovr                                ...
# clf__degree                        : 3                                  ...
# clf__gamma                         : scale                              ...
# clf__kernel                        : rbf                                ...
# clf__max_iter                      : -1                                 ...
# clf__probability                   : False                              ...
# clf__random_state                  : 1                                  ...
# clf__shrinking                     : True                               ...
# clf__tol                           : 0.001                              ...
# clf__verbose                       : False                              ...

# %%
param_range = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]

set1 = {'clf__C': param_range,
        'clf__kernel': ['linear']}

set2 = {'clf__C': param_range,
        'clf__gamma': param_range,
        'clf__kernel': ['rbf']}

param_grid = [set1, set2]

# %%
from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(estimator=pipe_svc, 
                  param_distributions=param_grid,
                  n_iter = 10,
                  scoring='accuracy', 
                  cv=10,
                  n_jobs=-1)

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('scl', StandardScaler()),
#                                              ('clf', SVC(random_state=1))]),
#                    n_jobs=-1,
#                    param_distributions=[{'clf__C': [0.0001, 0.001, 0.01, 0.1,
#                                                     1.0, 10.0, 100.0, 1000.0],
#                                          'clf__kernel': ['linear']},
#                                         {'clf__C': [0.0001, 0.001, 0.01, 0.1,
#                                                     1.0, 10.0, 100.0, 1000.0],
#                                          'clf__gamma': [0.0001, 0.001, 0.01,
#                                                         0.1, 1.0, 10.0, 100.0,
#                                                         1000.0],
#                                          'clf__kernel': ['rbf']}],
#                    scoring='accuracy')

# %%
# Get parameter names
for k, v in rs.get_params().items():
    print(f"{k:35.35s}: {str(v):35.35}...")
# Out:
# cv                                 : 10                                 ...
# error_score                        : nan                                ...
# estimator__memory                  : None                               ...
# estimator__steps                   : [('scl', StandardScaler()), ('clf',...
# estimator__verbose                 : False                              ...
# estimator__scl                     : StandardScaler()                   ...
# estimator__clf                     : SVC(random_state=1)                ...
# estimator__scl__copy               : True                               ...
# estimator__scl__with_mean          : True                               ...
# estimator__scl__with_std           : True                               ...
# estimator__clf__C                  : 1.0                                ...
# estimator__clf__break_ties         : False                              ...
# estimator__clf__cache_size         : 200                                ...
# estimator__clf__class_weight       : None                               ...
# estimator__clf__coef0              : 0.0                                ...
# estimator__clf__decision_function_s: ovr                                ...
# estimator__clf__degree             : 3                                  ...
# estimator__clf__gamma              : scale                              ...
# estimator__clf__kernel             : rbf                                ...
# estimator__clf__max_iter           : -1                                 ...
# estimator__clf__probability        : False                              ...
# estimator__clf__random_state       : 1                                  ...
# estimator__clf__shrinking          : True                               ...
# estimator__clf__tol                : 0.001                              ...
# estimator__clf__verbose            : False                              ...
# estimator                          : Pipeline(steps=[('scl', StandardSca...
# n_iter                             : 10                                 ...
# n_jobs                             : -1                                 ...
# param_distributions                : [{'clf__C': [0.0001, 0.001, 0.01, 0...
# pre_dispatch                       : 2*n_jobs                           ...
# random_state                       : None                               ...
# refit                              : True                               ...
# return_train_score                 : False                              ...
# scoring                            : accuracy                           ...
# verbose                            : 0                                  ...

# %%
df = pd.DataFrame(rs.cv_results_)
display(df)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.008533      0.000698         0.001483        0.000059
# 1       0.012548      0.004367         0.002208        0.000287
# 2       0.019149      0.007266         0.003454        0.002156
# 3       0.004816      0.000142         0.000885        0.000084
# 4       0.004506      0.000322         0.001011        0.000408
# 5       0.017353      0.004169         0.003001        0.001388
# 6       0.012879      0.004229         0.002088        0.000089
# 7       0.013889      0.004713         0.004472        0.004683
# 8       0.005666      0.001775         0.001105        0.000307
# 9       0.018549      0.004275         0.002538        0.000552
#
#   param_clf__kernel param_clf__gamma param_clf__C  \
# 0               rbf              0.1        100.0
# 1               rbf            100.0       0.0001
# 2               rbf           1000.0          1.0
# 3               rbf             0.01       1000.0
# 4               rbf             0.01        100.0
# 5               rbf              1.0       1000.0
# 6               rbf             0.01        0.001
# 7               rbf           1000.0       0.0001
# 8               rbf             0.01         10.0
# 9               rbf            100.0         0.01
#
#                                               params  split0_test_score  \
# 0  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...              0.925
# 1  {'clf__kernel': 'rbf', 'clf__gamma': 100.0, 'c...              0.625
# 2  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...              0.625
# 3  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.950
# 4  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.950
# 5  {'clf__kernel': 'rbf', 'clf__gamma': 1.0, 'clf...              0.625
# 6  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.625
# 7  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...              0.625
# 8  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.950
# 9  {'clf__kernel': 'rbf', 'clf__gamma': 100.0, 'c...              0.625
#
#    split1_test_score  ...  split3_test_score  split4_test_score  \
# 0              1.000  ...              1.000              0.950
# 1              0.625  ...              0.625              0.625
# 2              0.625  ...              0.625              0.625
# 3              1.000  ...              0.975              0.950
# 4              1.000  ...              0.950              0.950
# 5              0.625  ...              0.625              0.625
# 6              0.625  ...              0.625              0.625
# 7              0.625  ...              0.625              0.625
# 8              1.000  ...              0.975              1.000
# 9              0.625  ...              0.625              0.625
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0              0.875              0.925              1.000           0.974359
# 1              0.625              0.625              0.625           0.641026
# 2              0.625              0.625              0.625           0.641026
# 3              0.900              0.950              1.000           0.948718
# 4              0.900              0.950              0.975           0.974359
# 5              0.625              0.625              0.650           0.641026
# 6              0.625              0.625              0.625           0.641026
# 7              0.625              0.625              0.625           0.641026
# 8              0.950              0.975              0.975           0.974359
# 9              0.625              0.625              0.625           0.641026
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.974359         0.957372        0.038753                4
# 1           0.641026         0.628205        0.006410                6
# 2           0.641026         0.628205        0.006410                6
# 3           1.000000         0.967372        0.031794                2
# 4           1.000000         0.964936        0.029979                3
# 5           0.641026         0.630705        0.009018                5
# 6           0.641026         0.628205        0.006410                6
# 7           0.641026         0.628205        0.006410                6
# 8           1.000000         0.979936        0.018726                1
# 9           0.641026         0.628205        0.006410                6
#
# [10 rows x 21 columns]

# %%
df = df.sort_values(by=['rank_test_score'])
display(df.head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.005666      0.001775         0.001105        0.000307
# 3       0.004816      0.000142         0.000885        0.000084
# 4       0.004506      0.000322         0.001011        0.000408
# 0       0.008533      0.000698         0.001483        0.000059
# 5       0.017353      0.004169         0.003001        0.001388
#
#   param_clf__kernel param_clf__gamma param_clf__C  \
# 8               rbf             0.01         10.0
# 3               rbf             0.01       1000.0
# 4               rbf             0.01        100.0
# 0               rbf              0.1        100.0
# 5               rbf              1.0       1000.0
#
#                                               params  split0_test_score  \
# 8  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.950
# 3  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.950
# 4  {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'cl...              0.950
# 0  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...              0.925
# 5  {'clf__kernel': 'rbf', 'clf__gamma': 1.0, 'clf...              0.625
#
#    split1_test_score  ...  split3_test_score  split4_test_score  \
# 8              1.000  ...              0.975              1.000
# 3              1.000  ...              0.975              0.950
# 4              1.000  ...              0.950              0.950
# 0              1.000  ...              1.000              0.950
# 5              0.625  ...              0.625              0.625
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 8              0.950              0.975              0.975           0.974359
# 3              0.900              0.950              1.000           0.948718
# 4              0.900              0.950              0.975           0.974359
# 0              0.875              0.925              1.000           0.974359
# 5              0.625              0.625              0.650           0.641026
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 8           1.000000         0.979936        0.018726                1
# 3           1.000000         0.967372        0.031794                2
# 4           1.000000         0.964936        0.029979                3
# 0           0.974359         0.957372        0.038753                4
# 5           0.641026         0.630705        0.009018                5
#
# [5 rows x 21 columns]

# %%
print(rs.best_score_)
print(rs.best_params_)
# Out:
# 0.9799358974358974
# {'clf__kernel': 'rbf', 'clf__gamma': 0.01, 'clf__C': 10.0}

# %% [markdown]
# - Note that grid search already refit the entire training data with the best parameters. You can check this from this setting.

# %%
rs.refit
# Out:
# True

# %%
y_pred = rs.predict(X_test)
testing_accuracy = rs.score(X_test,y_test)
print(f"Testing accuracy: {testing_accuracy:6.3f}")
# Out:
# Testing accuracy:  0.977

# %%
# To do this manually
clf = rs.best_estimator_
clf.fit(X_train, y_train)
testing_accuracy = clf.score(X_test,y_test)
print(f"Testing accuracy: {testing_accuracy:6.3f}")
# Out:
# Testing accuracy:  0.977
